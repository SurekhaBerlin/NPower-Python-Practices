# %% [markdown]
# <a href="https://colab.research.google.com/github/SurekhaBerlin/NPower-Python-Practices/blob/main/Course7Module1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Dataset

# %% [markdown]
# https://npowercanada-my.sharepoint.com/:f:/g/personal/geetu_sodhi_npowercanada_ca/IgA3-q0TOYCkSaLD33qXKdqJAQna0YsGFQzkYO3Y7-9s1o8?e=SgYebd

# %%
# !pip install openpyxl
import pandas as pd
df=pd.read_excel("BookInventory.xlsx")
df.head(7)
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
#                  BookISBN Status      Category  PurchaseCost
# 0    978-0-331-95055-01-4    Out         Crime         25.99
# 1  978-1-40020-96298-02-1    Out       Medical         12.99
# 2    978-0-553-81762-01-5     In        Travel         14.00
# 3    978-0-662-95055-01-2    Out       Cookery         18.99
# 4    978-1-128-95055-01-3    Out         Crime         11.99
# 5    978-0-419-96298-02-3    Out  Architecture         35.00
# 6  978-1-40020-81762-01-6     In        Travel         17.00

# %% [markdown]
# #Saving back to Excel

# %%
df.to_excel("NewData.xlsx",index=False)  # Saves without the index

# %% [markdown]
# #Reading from Csv

# %%
import pandas as pd
df=pd.read_csv("BookInventory.csv")
df.head()
# Out:
#                  BookISBN Status Category  PurchaseCost
# 0    978-0-331-95055-01-4    Out    Crime         25.99
# 1  978-1-40020-96298-02-1    Out  Medical         12.99
# 2    978-0-553-81762-01-5     In   Travel         14.00
# 3    978-0-662-95055-01-2    Out  Cookery         18.99
# 4    978-1-128-95055-01-3    Out    Crime         11.99

# %% [markdown]
# #Saving back to the Csv

# %%
df.to_csv("Data.csv", index=False)  # Saves without the index column

# %% [markdown]
# #Reading from Json

# %%
import pandas as pd
df=pd.read_json("customers.json")
df.head()
# Out:
#                                            customers
# 0  {'customer_id': 101, 'name': 'Aisha Khan', 'em...
# 1  {'customer_id': 102, 'name': 'David Chen', 'em...

# %%
#Since my json has nested structure so we have to normalize it

import pandas as pd

# Load the JSON file
df = pd.read_json("customers.json")



df_customers = pd.DataFrame(df["customers"])
df_purchases = pd.json_normalize(df["customers"], "purchase_history", ["customer_id"])


# Display the formatted DataFrame
print(df_customers)
print()
print(df_purchases)
# Out:
#                                            customers
# 0  {'customer_id': 101, 'name': 'Aisha Khan', 'em...
# 1  {'customer_id': 102, 'name': 'David Chen', 'em...
#
#   order_id        date  amount     status customer_id
# 0  ORD-001  2025-01-10   89.99  Completed         101
# 1  ORD-004  2025-02-14  129.50    Pending         101
# 2  ORD-002  2025-01-12   45.00  Completed         102

# %% [markdown]
# #SAVING IT BACK TO JSON

# %%
df.to_json("Datajson.json", orient="records", indent=4)

#When saving a Pandas DataFrame as a JSON file using df.to_json(), the orient and indent parameters control how the data is structured and formatted in JSON.

# %% [markdown]
# #Review of DATAFRAMES

# %% [markdown]
# ![datframe.png](data:image/png;base64,...)

# %% [markdown]
# ![Picture2.png](data:image/png;base64,...)

# %%
#Creating an Empty Dataframe

import pandas as pd
#Empty Dataframe
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#creating dataframe from csv file
df=pd.read_csv("BookInventory.csv")
df
# Out:
#                   BookISBN Status      Category  PurchaseCost
# 0     978-0-331-95055-01-4    Out         Crime         25.99
# 1   978-1-40020-96298-02-1    Out       Medical         12.99
# 2     978-0-553-81762-01-5     In        Travel         14.00
# 3     978-0-662-95055-01-2    Out       Cookery         18.99
# 4     978-1-128-95055-01-3    Out         Crime         11.99
# 5     978-0-419-96298-02-3    Out  Architecture         35.00
# 6   978-1-40020-81762-01-6     In        Travel         17.00
# 7     978-0-518-96298-01-2    Out        Travel          9.99
# 8     978-0-447-96298-02-6    Out     Gardening         12.50
# 9     978-0-394-81762-02-1     In       Cookery         17.50
# 10    978-1-119-95055-02-4     In     Gardening         13.50
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50

# %%
df.Category
# Out:
# 0            Crime
# 1          Medical
# 2           Travel
# 3          Cookery
# 4            Crime
# 5     Architecture
# 6           Travel
# 7           Travel
# 8        Gardening
# 9          Cookery
# 10       Gardening
# 11       Astronomy
# Name: Category, dtype: object

# %%
df[['Category','Status']]
# Out:
#         Category Status
# 0          Crime    Out
# 1        Medical    Out
# 2         Travel     In
# 3        Cookery    Out
# 4          Crime    Out
# 5   Architecture    Out
# 6         Travel     In
# 7         Travel    Out
# 8      Gardening    Out
# 9        Cookery     In
# 10     Gardening     In
# 11     Astronomy    Out

# %%
df.loc[2]
# Out:
# BookISBN        978-0-553-81762-01-5
# Status                            In
# Category                      Travel
# PurchaseCost                    14.0
# Name: 2, dtype: object

# %%
df.iloc[2]
# Out:
# BookISBN        978-0-553-81762-01-5
# Status                            In
# Category                      Travel
# PurchaseCost                    14.0
# Name: 2, dtype: object

# %%
df.loc[:,['Category','Status']]
# Out:
#         Category Status
# 0          Crime    Out
# 1        Medical    Out
# 2         Travel     In
# 3        Cookery    Out
# 4          Crime    Out
# 5   Architecture    Out
# 6         Travel     In
# 7         Travel    Out
# 8      Gardening    Out
# 9        Cookery     In
# 10     Gardening     In
# 11     Astronomy    Out

# %%
df.loc[1:4,['Status','Category','PurchaseCost']]
# Out:
#   Status Category  PurchaseCost
# 1    Out  Medical         12.99
# 2     In   Travel         14.00
# 3    Out  Cookery         18.99
# 4    Out    Crime         11.99

# %%
df.loc[1:4, 'Status':'PurchaseCost']
# Out:
#   Status Category  PurchaseCost
# 1    Out  Medical         12.99
# 2     In   Travel         14.00
# 3    Out  Cookery         18.99
# 4    Out    Crime         11.99

# %%
df.iloc[1:5,1:4]
# Out:
#   Status Category  PurchaseCost
# 1    Out  Medical         12.99
# 2     In   Travel         14.00
# 3    Out  Cookery         18.99
# 4    Out    Crime         11.99

# %% [markdown]
# # **DATFRAME ATTRIBUTES**

# %%
#Return an int representing the number of elements in given dataframe.
df.size
# Out:
# 48

# %%
#Return a tuple representing the dimensions of the DataFrame.
df.shape
# Out:
# (12, 4)

# %%
#Return a list representing the axes of the DataFrame.
df.axes
# Out:
# [RangeIndex(start=0, stop=12, step=1),
#  Index(['BookISBN', 'Status', 'Category', 'PurchaseCost'], dtype='object')]

# %%
#Return an int representing the number of axes / array dimensions
df.ndim
# Out:
# 2

# %%
#The column labels of the DataFrame
df.columns
# Out:
# Index(['BookISBN', 'Status', 'Category', 'PurchaseCost'], dtype='object')

# %%
specific_category = df[(df['Category'] == 'Travel') | (df['Category'] == 'Crime')]
print(specific_category)
# Out:
#                  BookISBN Status Category  PurchaseCost
# 0    978-0-331-95055-01-4    Out    Crime         25.99
# 2    978-0-553-81762-01-5     In   Travel         14.00
# 4    978-1-128-95055-01-3    Out    Crime         11.99
# 6  978-1-40020-81762-01-6     In   Travel         17.00
# 7    978-0-518-96298-01-2    Out   Travel          9.99

# %%
#Return a Numpy representation of the DataFrame.
df.values
# Out:
# array([['978-0-331-95055-01-4', 'Out', 'Crime', 25.99],
#        ['978-1-40020-96298-02-1', 'Out', 'Medical', 12.99],
#        ['978-0-553-81762-01-5', 'In', 'Travel', 14.0],
#        ['978-0-662-95055-01-2', 'Out', 'Cookery', 18.99],
#        ['978-1-128-95055-01-3', 'Out', 'Crime', 11.99],
#        ['978-0-419-96298-02-3', 'Out', 'Architecture', 35.0],
#        ['978-1-40020-81762-01-6', 'In', 'Travel', 17.0],
#        ['978-0-518-96298-01-2', 'Out', 'Travel', 9.99],
#        ['978-0-447-96298-02-6', 'Out', 'Gardening', 12.5],
#        ['978-0-394-81762-02-1', 'In', 'Cookery', 17.5],
#        ['978-1-119-95055-02-4', 'In', 'Gardening', 13.5],
#        ['978-0-261-81762-01-2', 'Out', 'Astronomy', 24.5]], dtype=object)

# %% [markdown]
# **Adding a new column/ row**

# %%
#Adding column to the existing dataframe
df["FinalCost"] = df["PurchaseCost"] * 1.13
df
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.00    15.8200
# 3     978-0-662-95055-01-2    Out       Cookery         18.99    21.4587
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 6   978-1-40020-81762-01-6     In        Travel         17.00    19.2100
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 9     978-0-394-81762-02-1     In       Cookery         17.50    19.7750
# 10    978-1-119-95055-02-4     In     Gardening         13.50    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850

# %%
# Using loc() to add row or column/access/display row or column
# IMPORTANT: A column can also be added using loc() method. New row can be added to a dataframe using loc() method.
df["Discount"] = 0
df.loc[df["PurchaseCost"] > 20, "Discount"] = 5
df.loc[df["PurchaseCost"] <= 20, "Discount"] = 2
df
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.00    15.8200
# 3     978-0-662-95055-01-2    Out       Cookery         18.99    21.4587
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 6   978-1-40020-81762-01-6     In        Travel         17.00    19.2100
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 9     978-0-394-81762-02-1     In       Cookery         17.50    19.7750
# 10    978-1-119-95055-02-4     In     Gardening         13.50    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 1          2
# 2          2
# 3          2
# 4          2
# 5          5
# 6          2
# 7          2
# 8          2
# 9          2
# 10         2
# 11         5

# %%
#Adding a row

df.loc[3]=["988-0-201-89762-01-2","In","Cookery","34","38.42","5"]
df
# Out:
# /tmp/ipython-input-900041867.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '34' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[3]=["988-0-201-89762-01-2","In","Cookery","34","38.42","5"]
# /tmp/ipython-input-900041867.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '38.42' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[3]=["988-0-201-89762-01-2","In","Cookery","34","38.42","5"]
# /tmp/ipython-input-900041867.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[3]=["988-0-201-89762-01-2","In","Cookery","34","38.42","5"]
#                   BookISBN Status      Category PurchaseCost FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime        25.99   29.3687
# 1   978-1-40020-96298-02-1    Out       Medical        12.99   14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.0     15.82
# 3     988-0-201-89762-01-2     In       Cookery           34     38.42
# 4     978-1-128-95055-01-3    Out         Crime        11.99   13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.0     39.55
# 6   978-1-40020-81762-01-6     In        Travel         17.0     19.21
# 7     978-0-518-96298-01-2    Out        Travel         9.99   11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.5    14.125
# 9     978-0-394-81762-02-1     In       Cookery         17.5    19.775
# 10    978-1-119-95055-02-4     In     Gardening         13.5    15.255
# 11    978-0-261-81762-01-2    Out     Astronomy         24.5    27.685
#
#    Discount
# 0         5
# 1         2
# 2         2
# 3         5
# 4         2
# 5         5
# 6         2
# 7         2
# 8         2
# 9         2
# 10        2
# 11        5

# %% [markdown]
# df = df.set_index("BookID")
#
# if not df["BookID"].is_unique:
#     raise ValueError("BookID contains duplicates!")

# %%
#Adding column to the existing dataframe
df["PurchaseCost"] = pd.to_numeric(df["PurchaseCost"], errors="coerce")
df["FinalCost"] = df["PurchaseCost"] * 1.13

# %%
df.head()
# Out:
#                  BookISBN Status Category  PurchaseCost  FinalCost Discount
# 0    978-0-331-95055-01-4    Out    Crime         25.99    29.3687        5
# 1  978-1-40020-96298-02-1    Out  Medical         12.99    14.6787        2
# 2    978-0-553-81762-01-5     In   Travel         14.00    15.8200        2
# 3    988-0-201-89762-01-2     In  Cookery         34.00    38.4200        5
# 4    978-1-128-95055-01-3    Out    Crime         11.99    13.5487        2

# %%
df["Discount"] = 0
df.loc[df["PurchaseCost"] > 20, "Discount"] = 5
df.loc[df["PurchaseCost"] <= 20, "Discount"] = 2

# %%
df.head()
# Out:
#                  BookISBN Status Category  PurchaseCost  FinalCost  Discount
# 0    978-0-331-95055-01-4    Out    Crime         25.99    29.3687         5
# 1  978-1-40020-96298-02-1    Out  Medical         12.99    14.6787         2
# 2    978-0-553-81762-01-5     In   Travel         14.00    15.8200         2
# 3    988-0-201-89762-01-2     In  Cookery         34.00    38.4200         5
# 4    978-1-128-95055-01-3    Out    Crime         11.99    13.5487         2

# %%
#Books with Final Cost greater than Purchase cost

books_cost = df[df['FinalCost'] > df['PurchaseCost']]
books_cost
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.00    15.8200
# 3     988-0-201-89762-01-2     In       Cookery         34.00    38.4200
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 6   978-1-40020-81762-01-6     In        Travel         17.00    19.2100
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 9     978-0-394-81762-02-1     In       Cookery         17.50    19.7750
# 10    978-1-119-95055-02-4     In     Gardening         13.50    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 1          2
# 2          2
# 3          5
# 4          2
# 5          5
# 6          2
# 7          2
# 8          2
# 9          2
# 10         2
# 11         5

# %%
 #Fetch all books where Category is NOT "Cookery"
 df[df['Category'] != 'Cookery']
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.00    15.8200
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 6   978-1-40020-81762-01-6     In        Travel         17.00    19.2100
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 10    978-1-119-95055-02-4     In     Gardening         13.50    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 1          2
# 2          2
# 4          2
# 5          5
# 6          2
# 7          2
# 8          2
# 10         2
# 11         5

# %%
#Fetch rows for the 3 books with the highest PurchaseCost
df.nlargest(3, 'PurchaseCost')
# Out:
#                BookISBN Status      Category  PurchaseCost  FinalCost  \
# 5  978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 3  988-0-201-89762-01-2     In       Cookery         34.00    38.4200
# 0  978-0-331-95055-01-4    Out         Crime         25.99    29.3687
#
#    Discount
# 5         5
# 3         5
# 0         5

# %%
# Fetch books where PurchaseCost is between 15 and 25 AND Status is "In"
df[(df['PurchaseCost'] >= 15) & (df['PurchaseCost'] <= 25) & (df['Status'] == 'In')]
# Out:
#                  BookISBN Status Category  PurchaseCost  FinalCost  Discount
# 6  978-1-40020-81762-01-6     In   Travel          17.0     19.210         2
# 9    978-0-394-81762-02-1     In  Cookery          17.5     19.775         2

# %%
# Compute average PurchaseCost and fetch books costing more than average

average_cost = df['PurchaseCost'].mean()
df[df['PurchaseCost'] > average_cost]
# Out:
#                 BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0   978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 3   988-0-201-89762-01-2     In       Cookery         34.00    38.4200
# 5   978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 11  978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 3          5
# 5          5
# 11         5

# %%
avg_cost = df['PurchaseCost'].mean()
df[df['PurchaseCost'] > avg_cost]
# Out:
#                 BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0   978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 3   988-0-201-89762-01-2     In       Cookery         34.00    38.4200
# 5   978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 11  978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 3          5
# 5          5
# 11         5

# %% [markdown]
# **DELETING ROW/COLUMN**

# %%
df.drop("Discount", axis=1)  #drop a column
df
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.00    15.8200
# 3     988-0-201-89762-01-2     In       Cookery         34.00    38.4200
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 6   978-1-40020-81762-01-6     In        Travel         17.00    19.2100
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 9     978-0-394-81762-02-1     In       Cookery         17.50    19.7750
# 10    978-1-119-95055-02-4     In     Gardening         13.50    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 1          2
# 2          2
# 3          5
# 4          2
# 5          5
# 6          2
# 7          2
# 8          2
# 9          2
# 10         2
# 11         5

# %%
df.drop(3, axis=0)  #drop a row
df
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.00    15.8200
# 3     988-0-201-89762-01-2     In       Cookery         34.00    38.4200
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 6   978-1-40020-81762-01-6     In        Travel         17.00    19.2100
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 9     978-0-394-81762-02-1     In       Cookery         17.50    19.7750
# 10    978-1-119-95055-02-4     In     Gardening         13.50    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 1          2
# 2          2
# 3          5
# 4          2
# 5          5
# 6          2
# 7          2
# 8          2
# 9          2
# 10         2
# 11         5

# %%
df.drop([1,2] , axis=0)
df
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.00    15.8200
# 3     988-0-201-89762-01-2     In       Cookery         34.00    38.4200
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 6   978-1-40020-81762-01-6     In        Travel         17.00    19.2100
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 9     978-0-394-81762-02-1     In       Cookery         17.50    19.7750
# 10    978-1-119-95055-02-4     In     Gardening         13.50    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 1          2
# 2          2
# 3          5
# 4          2
# 5          5
# 6          2
# 7          2
# 8          2
# 9          2
# 10         2
# 11         5

# %% [markdown]
# **RENAMING ROW/ COLUMN**

# %%
df2=df.rename({'Rollno':'Roll', 'Total':'Tot', 'Percentage':'Per'}, axis= 'columns')
df2=df.rename(columns={'Rollno':'Roll', 'Total':'Tot', 'Percentage':'Per'})

# %% [markdown]
# **IMPORTING DATA FROM A CSV / EXCEL INTO DATAFRAME**

# %% [markdown]
# # ACCESSING DATA FROM A DATFRAME
# **SELECTING A PARTICULAR COLUMN**

# %%
df.BookISBN
# Out:
# 0       978-0-331-95055-01-4
# 1     978-1-40020-96298-02-1
# 2       978-0-553-81762-01-5
# 3       988-0-201-89762-01-2
# 4       978-1-128-95055-01-3
# 5       978-0-419-96298-02-3
# 6     978-1-40020-81762-01-6
# 7       978-0-518-96298-01-2
# 8       978-0-447-96298-02-6
# 9       978-0-394-81762-02-1
# 10      978-1-119-95055-02-4
# 11      978-0-261-81762-01-2
# Name: BookISBN, dtype: object

# %%
df['BookISBN']
# Out:
# 0       978-0-331-95055-01-4
# 1     978-1-40020-96298-02-1
# 2       978-0-553-81762-01-5
# 3       988-0-201-89762-01-2
# 4       978-1-128-95055-01-3
# 5       978-0-419-96298-02-3
# 6     978-1-40020-81762-01-6
# 7       978-0-518-96298-01-2
# 8       978-0-447-96298-02-6
# 9       978-0-394-81762-02-1
# 10      978-1-119-95055-02-4
# 11      978-0-261-81762-01-2
# Name: BookISBN, dtype: object

# %%
df[['BookISBN','Status']]
# Out:
#                   BookISBN Status
# 0     978-0-331-95055-01-4    Out
# 1   978-1-40020-96298-02-1    Out
# 2     978-0-553-81762-01-5     In
# 3     988-0-201-89762-01-2     In
# 4     978-1-128-95055-01-3    Out
# 5     978-0-419-96298-02-3    Out
# 6   978-1-40020-81762-01-6     In
# 7     978-0-518-96298-01-2    Out
# 8     978-0-447-96298-02-6    Out
# 9     978-0-394-81762-02-1     In
# 10    978-1-119-95055-02-4     In
# 11    978-0-261-81762-01-2    Out

# %% [markdown]
# # ACCESSING DATAFRAMES
#
# The data present in the DataFrames can be accessed using indexing and slicing.
# INDEXING
#
# **Indexing in DataFrames is of two types:**
#
# Label based Indexing
#
# Boolean Indexing.

# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %%
df
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 2     978-0-553-81762-01-5     In        Travel         14.00    15.8200
# 3     988-0-201-89762-01-2     In       Cookery         34.00    38.4200
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 6   978-1-40020-81762-01-6     In        Travel         17.00    19.2100
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 9     978-0-394-81762-02-1     In       Cookery         17.50    19.7750
# 10    978-1-119-95055-02-4     In     Gardening         13.50    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 1          2
# 2          2
# 3          5
# 4          2
# 5          5
# 6          2
# 7          2
# 8          2
# 9          2
# 10         2
# 11         5

# %%
#The loc() method is used for label based indexing. It accepts row/column labels as parameters.
#Dataframe.loc[start_row:end_row,start_col:end_col]

#To display the row with row label 2, the command is:
df.loc[2,:]

#where the symbol : indicates all columns.
# Out:
# BookISBN        978-0-553-81762-01-5
# Status                            In
# Category                      Travel
# PurchaseCost                    14.0
# FinalCost                      15.82
# Discount                           2
# Name: 2, dtype: object

# %%
df.loc[2]
# Out:
# BookISBN        978-0-553-81762-01-5
# Status                            In
# Category                      Travel
# PurchaseCost                    14.0
# FinalCost                      15.82
# Discount                           2
# Name: 2, dtype: object

# %%
# To access columns: use:
# DF.loc[:,start column:end column] Make sure not to miss the COLON BEFORE COMMA.
df.loc[:,"Discount"]
# Out:
# 0     5
# 1     2
# 2     2
# 3     5
# 4     2
# 5     5
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    5
# Name: Discount, dtype: int64

# %% [markdown]
# **We can easily retrieve a slice of rows and columns using loc() and iloc() methods.**
#
# The loc[] method is used to retrieve the group of rows and columns by labels or a boolean array present in the DataFrame. It takes only index labels, and if it exists in the called DataFrame, it returns the rows, columns, or DataFrame.

# %% [markdown]
# **The .iloc[] method is used retrieve the group of rows and columns at particular positions in the index so it only takes integers. It is used when the index label of the DataFrame **is other than numeric series of 0,1,2,	,n, or in the case when the user
# does not know the index label

# %% [markdown]
# ![pandas-different-between-loc-vs-iloc-2.webp](data:image/webp;base64,...)

# %%
df.iloc[::2,::2]

#every 2nd record and every alternate column
# Out:
#                   BookISBN   Category  FinalCost
# 0     978-0-331-95055-01-4      Crime    29.3687
# 2     978-0-553-81762-01-5     Travel    15.8200
# 4     978-1-128-95055-01-3      Crime    13.5487
# 6   978-1-40020-81762-01-6     Travel    19.2100
# 8     978-0-447-96298-02-6  Gardening    14.1250
# 10    978-1-119-95055-02-4  Gardening    15.2550

# %%
df.iloc[0:3,1:3]
# Out:
#   Status Category
# 0    Out    Crime
# 1    Out  Medical
# 2     In   Travel

# %% [markdown]
# # .at() - faster than loc when you need one specfic cell value

# %%
df.at[8,"Status"]
# Out:
# 'Out'

# %%
subset = df.loc[7:9, ["BookISBN", "Status"]]
print(subset)
# Out:
#                BookISBN Status
# 7  978-0-518-96298-01-2    Out
# 8  978-0-447-96298-02-6    Out
# 9  978-0-394-81762-02-1     In

# %%
subset = df.iloc[7:9, [0, 1]]
print(subset)
# Out:
#                BookISBN Status
# 7  978-0-518-96298-01-2    Out
# 8  978-0-447-96298-02-6    Out

# %% [markdown]
# **BOOLEAN INDEXING IN DATAFRAMES**
# Instead of selecting data on the basis of row or column labels we can also select the data based on their values present in the dataframe.

# %% [markdown]
# ![Picture2.png](data:image/png;base64,...)

# %%
# Books out of stock:

out_books = df[df["Status"] == "Out"]
print(out_books)
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime         25.99    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical         12.99    14.6787
# 4     978-1-128-95055-01-3    Out         Crime         11.99    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture         35.00    39.5500
# 7     978-0-518-96298-01-2    Out        Travel          9.99    11.2887
# 8     978-0-447-96298-02-6    Out     Gardening         12.50    14.1250
# 11    978-0-261-81762-01-2    Out     Astronomy         24.50    27.6850
#
#     Discount
# 0          5
# 1          2
# 4          2
# 5          5
# 7          2
# 8          2
# 11         5

# %%
#purchase cost > 20

df["PurchaseCost"] = df["PurchaseCost"].astype(int)

high_cost_books = df[df["PurchaseCost"] > 20]
print(high_cost_books)
# Out:
#                 BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0   978-0-331-95055-01-4    Out         Crime            25    29.3687
# 3   988-0-201-89762-01-2     In       Cookery            34    38.4200
# 5   978-0-419-96298-02-3    Out  Architecture            35    39.5500
# 11  978-0-261-81762-01-2    Out     Astronomy            24    27.6850
#
#     Discount
# 0          5
# 3          5
# 5          5
# 11         5

# %%
#Fetch books in Travel or Crime Category

specific_category = df[df["Category"].isin(["Travel", "Crime"])]
print(specific_category)
# Out:
#                  BookISBN Status Category  PurchaseCost  FinalCost  Discount
# 0    978-0-331-95055-01-4    Out    Crime            25    29.3687         5
# 2    978-0-553-81762-01-5     In   Travel            14    15.8200         2
# 4    978-1-128-95055-01-3    Out    Crime            11    13.5487         2
# 6  978-1-40020-81762-01-6     In   Travel            17    19.2100         2
# 7    978-0-518-96298-01-2    Out   Travel             9    11.2887         2

# %%
#books out and costs more than $20

out_expensive = df[(df["Status"] == "Out") & (df["PurchaseCost"] > 20)]
print(out_expensive)
# Out:
#                 BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0   978-0-331-95055-01-4    Out         Crime            25    29.3687
# 5   978-0-419-96298-02-3    Out  Architecture            35    39.5500
# 11  978-0-261-81762-01-2    Out     Astronomy            24    27.6850
#
#     Discount
# 0          5
# 5          5
# 11         5

# %%
#Purchasecost between 10-50
books_10_50 = df[df["PurchaseCost"].between(10, 50)]
books_10_50
# Out:
#                   BookISBN Status      Category  PurchaseCost  FinalCost  \
# 0     978-0-331-95055-01-4    Out         Crime            25    29.3687
# 1   978-1-40020-96298-02-1    Out       Medical            12    14.6787
# 2     978-0-553-81762-01-5     In        Travel            14    15.8200
# 3     988-0-201-89762-01-2     In       Cookery            34    38.4200
# 4     978-1-128-95055-01-3    Out         Crime            11    13.5487
# 5     978-0-419-96298-02-3    Out  Architecture            35    39.5500
# 6   978-1-40020-81762-01-6     In        Travel            17    19.2100
# 8     978-0-447-96298-02-6    Out     Gardening            12    14.1250
# 9     978-0-394-81762-02-1     In       Cookery            17    19.7750
# 10    978-1-119-95055-02-4     In     Gardening            13    15.2550
# 11    978-0-261-81762-01-2    Out     Astronomy            24    27.6850
#
#     Discount
# 0          5
# 1          2
# 2          2
# 3          5
# 4          2
# 5          5
# 6          2
# 8          2
# 9          2
# 10         2
# 11         5

# %% [markdown]
# #Fastest Finger First
#
# Books with FinalCost Higher than PurchaseCost
#
# Fetch all books where Category is not "Cookery" (use ~ or !=).
#
# Fetch rows for the 3 books with the highest PurchaseCost (use .nlargest()).
#
# Fetch books where PurchaseCost is between 15–25 and Status is "In".
#
# Compute average PurchaseCost and fetch books costing more than average.

# %% [markdown]
# **PLOTTING USING DATAFRAME**

# %%
data=pd.read_csv("BookInventory.csv")
data.head()
# Out:
#                  BookISBN Status Category  PurchaseCost
# 0    978-0-331-95055-01-4    Out    Crime         25.99
# 1  978-1-40020-96298-02-1    Out  Medical         12.99
# 2    978-0-553-81762-01-5     In   Travel         14.00
# 3    978-0-662-95055-01-2    Out  Cookery         18.99
# 4    978-1-128-95055-01-3    Out    Crime         11.99

# %%
import matplotlib.pyplot as plt

data.plot(x='Category', y='PurchaseCost', kind='scatter')
data=data.head(20)

plt.xticks(rotation=45)   # Rotate labels 45 degrees
plt.tight_layout()        # Adjust layout so nothing is cut off
plt.show()

# %%
data.plot(x='Category', y='PurchaseCost')
# Out:
# <Axes: xlabel='Category'>

# %%
data.plot(x='Category', y='PurchaseCost', kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
category_counts = data['Category'].value_counts()
category_counts.plot(kind='pie', autopct='%1.1f%%', figsize=(6,6), startangle=90)
plt.ylabel('')   # Remove y-axis label
plt.title("Category Distribution")
plt.show()
